# %% [markdown]
# # Phosphorus predictive model

# %% [markdown]
# This script performs a phosphorus budget on a lake using a two-box model. This phosphorus budget is applied on past data with known TP concentrations to determine the relative contribution of external and internal phosphorus loads. This approach can be applied on monomictic lakes with a summer stratified period and a winter mixed period.

# %% [markdown]
# **Author**: Tomy Doda, Surface Waters - Research and Management, Eawag\
# **Last update**: 21.04.2024

# %% [markdown]
# #### Required packages:
# - numpy
# - matplotlib
# - pandas
# - cmocean
# - scipy

# %%
# Import the packages
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'svg.fonttype':'none', 'font.sans-serif':'Arial','font.size': 12}) # "none": to export text as text
import pandas as pd
from datetime import datetime, timezone, UTC, timedelta
import math
import cmocean
from functions import *
# %matplotlib widget

# %% [markdown]
# #### Parameters

# %%
#lakename="LakeMurten"
lakename="LakeBaldegg"

# %%
method_Pin="function" # Options: "obs" (compute Pin from observations of TPin), "curve" (compute Pin from created Q-TPin curve), "function" (compute Pin from provided function Q=f(TPin) in function file)
method_epi="varying" # Options: "constant" (constant thermocline depth set during stratified period in Lake_info.csv), "varying" (thermocline depth 
# measured or modeled at different time steps)
method_anox="stratif" # Options: "stratif" (anoxic period matches stratified period), "specified" (the start of the anoxic period is specified manually in lake_info.csv),
# "estimated" (anoxic period based on empirical equation from Müller et al., (2012)).
method_netsed="Vollenweider" # Options: "Vollenweider", "Hanson" (only used in predictive model to compute the net sedimentation rate)

# %% [markdown]
# Time for which the phosphorus budget must be computed (if empty, use the time from the inflow data or the TP data depending which one has the lowest frequency):

# %%
# tdate_budget=np.array([]) # Example: tdate_budget=np.array([datetime(2024,1,1),datetime(2024,1,2),datetime(2024,1,3)]) 
#tdate_min_max=np.array([datetime(2008,1,1),datetime(2015,12,31)]) # If empty, time is the inflow data time
#tdate_min_max=np.array([datetime(2002,1,1),datetime(2015,12,31)]) # If empty, time is the inflow data time
tdate_min_max=np.array([datetime(1985,4,1),datetime(2015,12,31)]) # If empty, time is the inflow data time
tdate_list=[tdate_min_max[0]]

while tdate_list[-1]<datetime(tdate_min_max[1].year,tdate_min_max[1].month,1):                                                  
    month_nb=tdate_list[-1].month
    year_nb=tdate_list[-1].year
    if month_nb==12:
        month_nb=1
        year_nb+=1
    else:
        month_nb+=1
    tdate_list.append(datetime(year_nb,month_nb,1))
tdate_budget=np.array(tdate_list) # Monthly interval

# %%
savefig_bool=False

# %% [markdown]
# ## 1. Load the data

# %%
#date_format = lambda x: pd.to_datetime(x, format="%d.%m")
df_lake=pd.read_csv("../Data/"+lakename+"/Lake_info.csv", sep=",",header=None,skiprows=1,usecols=[1],dtype=str) # Lake information
df_lake=df_lake.T # Transpose
df_lake.columns=["z_epi","t_stratif_start","t_stratif_end","t_anoxic_start","T_epi","T_hypo","TPsed","Kz","sigma_max","NS_max"]
df_lake.to_csv('lake_parameters.csv', sep=",",index=False,header=True) # Save the transposed dataframe
df_lake=pd.read_csv("lake_parameters.csv", sep=",",header=0,parse_dates=["t_stratif_start","t_stratif_end","t_anoxic_start"],date_format="%d.%m") # Load it again to have the correct date format 
Kz=df_lake["Kz"][0]
TPsed=df_lake["TPsed"][0]

# %%
df_hypso=pd.read_csv("../Data/"+lakename+"/Hypsometry.csv", sep=",",header=0,names=["z_hypso","A_hypso"]) # Hypsometry
z_hypso=df_hypso["z_hypso"].to_numpy()
df_lake["z_max"]=np.max(z_hypso)
A_hypso=df_hypso["A_hypso"].to_numpy()
A0=A_hypso[z_hypso==0]
V_hypso=np.concatenate((np.mean([A_hypso[1:],A_hypso[:-1]],axis=0)*(z_hypso[1:]-z_hypso[:-1]),np.array([0]))) # Volume of each layer [m3]
V_lake=np.nansum(V_hypso) # [m3]
z_mean=V_lake/A0 # [m]

# %%
#date_format = lambda x: pd.to_datetime(x, format='%d.%m.%Y')
simstrat_file="../Data/"+lakename+"/"+lakename+"_T_SIMSTRAT.dat"
df_inflows=pd.read_csv("../Data/"+lakename+"/Inflows.csv", sep=",",parse_dates=["Date"],date_format='%d.%m.%Y') # Inflows
#df_outflows=pd.read_csv("..\Data\\"+lakename+"\Outflows.csv", sep=",",parse_dates=["Date"],date_parser=date_format) # Outflows
df_TP=pd.read_csv("../Data/"+lakename+"/TP.csv", sep=",") # TP concentrations (to compare with model)
tdate_TP=np.array([datetime.strptime(datestr,"%d/%m/%Y") for datestr in df_TP.columns[1:]]) # Dates with measured TP
tnum_TP=np.array([d.replace(tzinfo=timezone.utc).timestamp() for d in tdate_TP])

# %%
if method_Pin=="curve" or method_Pin=="function":
    df_Q=pd.read_csv("../Data/"+lakename+"/Discharges.csv", sep=",",parse_dates=["Date"],date_format='%d.%m.%Y') 
    tnum_Q=df_Q["Date"].to_numpy().astype('datetime64[s]').astype(np.int64)
    tdate_Q=df_Q["Date"].to_numpy().astype('datetime64[s]').astype(datetime)
    Qval=df_Q.values[:,np.arange(1,len(df_Q.columns),1)].astype(float)

# %% [markdown]
# Set the time for the budget:

# %%
if not list(tdate_budget): # Empty: take the time from the lowest frequency between inflow data and TP data
    if method_Pin!="obs":
        print("The model can only be run during the inflow measurement period because the simulation period has not been defined.")
    dt_inflows=np.nanmean(np.diff(df_inflows["Date"].to_numpy().astype('datetime64[s]').astype(np.int64)))
    dt_TP=np.nanmean(np.diff(tnum_TP))
    ind_low_freq=np.argmax(np.array([dt_inflows,dt_TP])) # Lowest frequency
    if ind_low_freq==0: # Take inflows time
        tdate_budget=df_inflows["Date"].to_numpy().astype('datetime64[s]').astype(datetime)
    else: # Take TP time
        tdate_budget=tdate_TP
    
    if list(tdate_min_max): # Not empty
        tdate_budget=tdate_budget[np.logical_and(tdate_budget>tdate_min_max[0],tdate_budget<tdate_min_max[1])]

# %%
tnum_budget=np.array([dateval.replace(tzinfo=timezone.utc).timestamp() for dateval in tdate_budget])

# %% [markdown]
# Compute the thermocline depth at each TP measurement timestep (from constant thermocline or from measured/modelled temperature):

# %%
if method_epi=="constant":
    tdate_start=df_lake["t_stratif_start"].to_numpy().astype('datetime64[s]').astype(datetime)[0]
    tdate_end=df_lake["t_stratif_end"].to_numpy().astype('datetime64[s]').astype(datetime)[0]
    hepi_TP=compute_hepi_constant(tdate_TP,tdate_start,tdate_end,hepi=df_lake["z_epi"][0],zmax=df_lake["z_max"][0]) # At time steps of TP measurements
    hepi_budget=compute_hepi_constant(tdate_budget,tdate_start,tdate_end,hepi=df_lake["z_epi"][0],zmax=df_lake["z_max"][0]) # At time steps of P budget
else:
    tnum_T, depth_T, tempval=extract_simstrat_T(simstrat_file) # Extract Simstrat temperature data
    bool_period=np.logical_and(tnum_T>=tnum_budget[0],tnum_T<=tnum_budget[-1]) # Select period of interest
    #hepi_TP,hepi_T=compute_hepi_varying(tnum_TP,tnum_T[bool_period],depth_T,tempval[:,bool_period],zmax=df_lake["z_max"][0]) # At time steps of TP measurements
    hepi_TP,hepi_T=compute_hepi_varying(tnum_TP,tnum_T,depth_T,tempval,zmax=df_lake["z_max"][0]) # At time steps of TP measurements
    hepi_budget,_=compute_hepi_varying(tnum_budget,tnum_T[bool_period],depth_T,tempval[:,bool_period],zmax=df_lake["z_max"][0]) # At time steps of P budget
    
Vepi=np.full(len(hepi_budget),np.nan)
Atherm=np.full(len(hepi_budget),np.nan)
for kt in range(len(hepi_budget)):
    Vepi[kt]=np.nansum(V_hypso[z_hypso<=hepi_budget[kt]])
    Atherm[kt]=A_hypso[np.where(z_hypso>=hepi_budget[kt])[0][0]]
hepi_model=Vepi/A0 # Thermocline depth for a box of the same volume as the epilimnion

# %% [markdown]
# Tepi, Thypo

# %%
depthval=df_TP["Depth [m]"].values
TPepi,TPhypo=compute_TP_2boxes(depthval,df_TP.values[:,1:],hepi_TP)
# Temperature in epilimnion and hypolimnion:
if method_epi=="varying":
    #T_epi,T_hypo=compute_TP_2boxes(depth_T,tempval[:,bool_period],hepi_T)
    #T_epi=np.interp(tnum_TP,tnum_T[bool_period],T_epi)
    #T_hypo=np.interp(tnum_TP,tnum_T[bool_period],T_hypo)
    T_epi,T_hypo=compute_TP_2boxes(depth_T,tempval,hepi_T)
    T_epi=np.interp(tnum_TP,tnum_T,T_epi)
    T_hypo=np.interp(tnum_TP,tnum_T,T_hypo)
else:
    T_epi=np.full(len(tnum_TP),df_lake["T_epi"][0]) # Annual average
    T_hypo=np.full(len(tnum_TP),df_lake["T_hypo"][0])
T_epi_budget=np.interp(tnum_budget,tnum_TP,T_epi)
T_hypo_budget=np.interp(tnum_budget,tnum_TP,T_hypo)

# %% [markdown]
# Initial conditions

# %%
TPepi_0=TPepi[np.argmin(np.abs(tnum_TP-tnum_budget[0]))]
TPhypo_0=TPhypo[np.argmin(np.abs(tnum_TP-tnum_budget[0]))]

# %%
TPepi_compare=TPepi[np.logical_and(tnum_TP>=tnum_budget[0],tnum_TP<=tnum_budget[-1])]
TPhypo_compare=TPhypo[np.logical_and(tnum_TP>=tnum_budget[0],tnum_TP<=tnum_budget[-1])]
tdate_compare=tdate_TP[np.logical_and(tnum_TP>=tnum_budget[0],tnum_TP<=tnum_budget[-1])]

# %%
fig,ax=plt.subplots(2,1,figsize=(10,10),sharex=True)
#ax[0].plot([datetime.fromtimestamp(tnum,UTC) for tnum in tnum_T],hepi_T,'-k')
ax[0].plot(tdate_TP,hepi_TP,':k')
ax[0].plot(tdate_budget,hepi_budget,'.k')
ax[0].set_ylabel('$h_{\\rm epi}$ [m]')
ax[0].invert_yaxis()

ax[1].plot(tdate_TP,TPepi,':',color="C0")
p1,=ax[1].plot(tdate_compare,TPepi_compare,'.',color="C0")
ax[1].plot(tdate_TP,TPhypo,':',color="C1")
p2,=ax[1].plot(tdate_compare,TPhypo_compare,'.',color="C1")
plt.legend([p1,p2],['TP$_{\\rm epi}$','TP$_{\\rm hypo}$'])
ax[1].set_ylabel('TP [mg m$^{-3}$]')
# Out:
# Text(0, 0.5, 'TP [mg m$^{-3}$]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 2. Compute the terms of the mass balance

# %% [markdown]
# #### Phosphorus load from inflows ($P_{\rm in}$)

# %%
tnum_inflows=df_inflows["Date"].to_numpy().astype('datetime64[s]').astype(np.int64)
tdate_inflows=df_inflows["Date"].to_numpy().astype('datetime64[s]').astype(datetime)
Q_inflows=df_inflows.values[:,np.arange(1,len(df_inflows.columns),2)].astype(float)
TP_inflows=df_inflows.values[:,np.arange(2,len(df_inflows.columns),2)].astype(float)

# %%
if method_Pin=="obs":
    Pin,Qin_budget,tnum_budget2=compute_river_load_from_obs(tnum_inflows,Q_inflows,TP_inflows,tnum_budget,calculation="average") # [tons-P yr-1]
    valkeep=~np.isnan(Pin)
    Pin=Pin[valkeep]
    tnum_budget=tnum_budget[valkeep]
    tdate_budget=tdate_budget[valkeep]
elif method_Pin=="curve": # From Q-TP curve
    # 1- Inflow-specific curve
    Pin,Qin_curve,tnum_budget2,param_curve,R2=compute_river_load_from_curve(Q_inflows,TP_inflows,tnum_Q,Qval,tnum_budget,method="power",calculation="average") # [tons-P yr-1]

    # 2- Global curve:
    Qin_tot=np.sum(Q_inflows,axis=1)
    TPin_tot=np.sum(Q_inflows*TP_inflows,axis=1)/Qin_tot
    Qval_tot=np.sum(Qval,axis=1)
    Pin_global,Qin_curve_global,tnum_budget_global,param_curve_global,R2_global=compute_river_load_from_curve(np.array([Qin_tot,]).transpose(),np.array([TPin_tot,]).transpose(),tnum_Q,np.array([Qval_tot,]).transpose(),tnum_budget,method="power",calculation="average") # [tons-P yr-1]

    # Print parameters of relationship of Müller et al. (2012) with Q [1e6 m3/yr] and TP [ug/L]
    a_param=param_curve[0,:]*(1e6/(365*24*3600))**param_curve[1,:]
    print("Parameters (inflow-specific): a={},b={}".format(a_param,param_curve[1,:])) 
    a_param_global=param_curve_global[0,0]*(1e6/(365*24*3600))**param_curve_global[1,0]
    print("Parameters (global): a={:.2f},b={:.2f}".format(a_param_global,param_curve_global[1,0]))
elif method_Pin=="function":
    Qin_tot=np.sum(Qval,axis=1)
    TPin_curve=discharge_TP(tnum_Q,Qin_tot)
    tnum_budget2,Pin_budget,_=average_between(tnum_budget,tnum_Q,TPin_curve*Qin_tot*86400*365*1e-9) # Average between dates
    _,Qin_budget,_=average_between(tnum_budget,tnum_Q,Qin_tot)
    Pin=np.concatenate((Pin_budget,np.array([np.nan])),axis=0) # Add a nan value at the end
    tnum_budget2=np.concatenate((tnum_budget,np.array([np.nan])),axis=0) # Add a nan value at the end      
    Qin_budget=np.concatenate((Qin_budget,np.array([np.nan])),axis=0) # Add a nan value at the end
else:
    raise Exception("Wrong Pin method specified")

# %%
if method_Pin=="curve": 
    Pin_obs,_=compute_river_load_from_obs(tnum_inflows,Q_inflows,TP_inflows,tnum_budget,calculation="average") # [tons-P yr-1]
    
    # Q-TP curves for each inflow
    fig,ax=plt.subplots(1,Q_inflows.shape[1],figsize=(10,3))
    col_inflows=plt.get_cmap("tab10")
    hp_all=[]
    legname=[]
    period1_logical=tnum_inflows<datetime(1996,1,1).replace(tzinfo=timezone.utc).timestamp()
    for kin in range(Q_inflows.shape[1]):
        
        hp1,=ax[kin].plot(Q_inflows[np.logical_and(period1_logical,Q_inflows[:,kin]>0),kin],TP_inflows[np.logical_and(period1_logical,Q_inflows[:,kin]>0),kin],
                'o',markersize=2,color=col_inflows(kin),markerfacecolor='w')
        hp2,=ax[kin].plot(Q_inflows[np.logical_and(~period1_logical,Q_inflows[:,kin]>0),kin],TP_inflows[np.logical_and(~period1_logical,Q_inflows[:,kin]>0),kin],
                    'o',markersize=2,color=col_inflows(kin))
        ax[kin].plot(Q_inflows[Q_inflows[:,kin]>0,kin],param_curve[0,kin]*Q_inflows[Q_inflows[:,kin]>0,kin]**param_curve[1,kin],'-',color=col_inflows(kin))
        ax[kin].set_xscale("log")
        ax[kin].set_yscale("log")
        ax[kin].legend([hp1,hp2],["1985-1996","1996-2015"])
        column_name=df_inflows.columns[2*kin+1]
        ax[kin].set_title(column_name[2:column_name.find(" [m3")])
        ax[kin].set_xlabel("$Q_{in}$ [m$^{3}$.s$^{-1}$]")
        ax[kin].set_ylabel("$TP_{in}$ [mg.m$^{-3}$]")
    fig.set_tight_layout(True)

    # Global Q-TP curve
    fig,ax=plt.subplots(1,1,figsize=(5,5))
    hp1,=ax.plot(Qin_tot[np.logical_and(period1_logical,Qin_tot>0)],TPin_tot[np.logical_and(period1_logical,Qin_tot>0)],
            'ko',markersize=2,markerfacecolor='w')
    hp2,=ax.plot(Qin_tot[np.logical_and(~period1_logical,Qin_tot>0)],TPin_tot[np.logical_and(~period1_logical,Qin_tot>0)],
            'ko',markersize=2)
    ax.plot(Qin_tot[Qin_tot>0],param_curve_global[0,0]*Qin_tot[Qin_tot>0]**param_curve_global[1,0],'r-')
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.legend([hp1,hp2],["1985-1996","1996-2015"])
    ax.set_xlabel("$Q_{in}$ [m$^{3}$.s$^{-1}$]")
    ax.set_ylabel("$TP_{in}$ [mg.m$^{-3}$]")
    fig.set_tight_layout(True)

    # Time series
    fig,ax=plt.subplots(2,1,figsize=(10,10),sharex=True)
    ax[0].plot(tdate_Q,np.nansum(Qval,axis=1))
    ax[0].plot(tdate_budget,Qin_curve,'.-')
    ax[0].set_ylabel("$Q$ [m$^3$/s]")
    ax[0].legend(["obs","from curve"])

    #Pin based on the Q-TP relationship from Müller et al. (2012)
    Qin_tot_M=np.sum(Qval,axis=1)
    TPin_curve_M=discharge_TP(tnum_Q,Qin_tot_M)
    #Pin_M1=np.interp(tnum_budget,tnum_Q,TPin_curve_M*Qin_tot_M,left=np.nan,right=np.nan)*86400*365*1e-9 # [tons-P yr-1]
    tnum_budget2,Pin_M2,_=average_between(tnum_budget,tnum_Q,TPin_curve_M*Qin_tot_M*86400*365*1e-9) # Average between dates
    Pin_M2=np.concatenate((Pin_M2,np.array([np.nan])))
    
    ax[1].plot(tdate_budget,Pin_obs)
    #ax[1].plot(tdate_budget,Pin)
    tdate_budget_global=np.full(tnum_budget_global.shape,None)
    tdate_budget_global[~np.isnan(tnum_budget_global)]=np.array([datetime.fromtimestamp(tnum,UTC) for tnum in tnum_budget_global[~np.isnan(tnum_budget_global)]])
    ax[1].plot(tdate_budget_global[tdate_budget_global!=None],Pin_global[tdate_budget_global!=None],'.-')
    ax[1].plot(tdate_budget,Pin_M2,'.-')
    ax[1].legend(["obs","from global curve","from Müller"])
    ax[1].set_ylabel("$P_{in}$ [tons-P/yr]")
elif method_Pin=="obs":
    # Time series
    fig,ax=plt.subplots(2,1,figsize=(10,10),sharex=True)
    p1,=ax[0].plot(tdate_inflows,np.sum(Q_inflows,axis=1),'.-',color="C0")
    ax[0].set_ylabel("$Q$ [m$^3$/s]")
    ax_right = ax[0].twinx()
    p2,=ax_right.plot(tdate_inflows,np.sum(Q_inflows*TP_inflows,axis=1)/np.sum(Q_inflows,axis=1),'.-',color="C1")
    ax_right.set_ylabel("$TP_{\\rm in}$ [mg.m$^{-3}$]")
    ax[0].legend([p1,p2],["$Q$","$TP_{\\rm in}$"])

    ax[1].plot(tdate_inflows,np.sum(Q_inflows*TP_inflows*86400*365*1e-9,axis=1),'k.-')
    ax[1].plot(tdate_budget,Pin,'r.-')
    ax[1].set_ylabel("$P_{\\rm in}$ [tons.yr$^{-1}$]")
    ax[1].legend(["obs","averaged"])

# %%
fig,ax=plt.subplots(3,1,figsize=(8,8),sharex=True)
legname=[]
for kriver in range(Q_inflows.shape[1]):
    column_name=df_inflows.columns[2*kriver+1]
    legname.append(column_name[2:column_name.find(" [m3")])
    ax[0].plot(df_inflows["Date"],Q_inflows[:,kriver],'.-',markersize=8)
    ax[1].plot(df_inflows["Date"],TP_inflows[:,kriver],'.-',markersize=8)
    ax[2].plot(df_inflows["Date"],Q_inflows[:,kriver]*TP_inflows[:,kriver]*86400*365*1e-9,'.-',markersize=8)
ax[0].set_ylabel('$Q_{\\rm in}$ [m$^3$/s]')
ax[1].set_ylabel('$TP_{\\rm in}$ [mg-P/m$^3$]')
ax[2].set_ylabel('$P_{\\rm in}$ [tons-P/yr]')
ax[0].legend(legname)

# Save figure
if savefig_bool:
    fig.savefig("../Figures/Pin.png",dpi=400)
    fig.savefig("../Figures/Pin.svg")
    print('Figure saved!')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 3. Predictive mass balance model

# %%
if method_Pin=="curve":
    Qout_budget=Qin_curve # Assumption: Qout=Qin
else: 
    Qout_budget=Qin_budget # Assumption: Qout=Qin

# %%
if method_anox=="stratif":
    bool_anox=hepi_budget<df_lake["z_max"][0]
elif method_anox=="specified":
    bool_anox=compute_anoxia_dates(tdate_budget,df_lake["t_anoxic_start"].to_numpy().astype('datetime64[s]').astype(datetime)[0],hepi_budget,df_lake["z_max"][0]) 
else:
    if method_epi=="varying":
        # Determine stratified periods accurately
        tnum_stratif=compute_stratified_periods(tnum_T[bool_period],hepi_T,df_lake["z_max"][0])
    else:
        all_years=np.array([tdate.year for tdate in tdate_budget])
        unique_years=np.unique(all_years)
        tnum_stratif=np.full((2,len(unique_years)),np.nan)
        for ky in range(len(unique_years)):
            tnum_stratif[:,ky]=np.array([datetime(unique_years[ky],tdate_start.month,tdate_start.day).replace(tzinfo=timezone.utc).timestamp(),\
                               datetime(unique_years[ky],tdate_end.month,tdate_end.day).replace(tzinfo=timezone.utc).timestamp()])
    bool_anox,ndays_to_anox,tstart_anox=compute_anoxia_red(tnum_budget,hepi_model,z_mean,tnum_stratif=tnum_stratif)

# %%
if type(df_lake["sigma_max"][0])==np.float64:
    sigma_max=df_lake["sigma_max"][0]
else:
    sigma_max=np.nan
    
if type(df_lake["NS_max"][0])==np.float64:
    P_NS_max=df_lake["NS_max"][0] 
else:
    P_NS_max=np.nan

#MODIFY parameters
#P_NS_max=4.2
#TPcritval=30
#P_NS_max=np.nan
TPcrit=np.nan
Pin2=Pin
TPsed2=TPsed


tnum_predict,TPepi_predict,TPepi_range,TPhypo_predict,TPhypo_range,P_fluxes,param=predict_TP_model(tnum_budget,bool_anox,Pin2,Qout_budget,hepi_budget,TPepi_0,TPhypo_0,TPsed2,\
                                                                                   z_hypso,A_hypso,T_hypo_budget,T_epi_budget,sigma_max=sigma_max,P_NS_max=P_NS_max,TPcrit=TPcrit,\
                                                                                             method_sed=method_netsed,method_remob="Carter",show_output=True)
# Out:
# 1985-04-01 00:00:00+00:00: TP_lake=206.29 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1985-05-01 00:00:00+00:00: TP_lake=202.81 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1985-06-01 00:00:00+00:00: TP_lake=212.21 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1985-07-01 00:00:00+00:00: TP_lake=211.36 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1985-08-01 00:00:00+00:00: TP_lake=209.43 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1985-09-01 00:00:00+00:00: TP_lake=207.74 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1985-10-01 00:00:00+00:00: TP_lake=208.72 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1985-11-01 00:00:00+00:00: TP_lake=206.67 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1985-12-01 00:00:00+00:00: TP_lake=204.55 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-01-01 00:00:00+00:00: TP_lake=182.95 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-02-01 00:00:00+00:00: TP_lake=179.04 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-03-01 00:00:00+00:00: TP_lake=176.51 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-04-01 00:00:00+00:00: TP_lake=140.40 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-05-01 00:00:00+00:00: TP_lake=137.55 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-06-01 00:00:00+00:00: TP_lake=143.26 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-07-01 00:00:00+00:00: TP_lake=144.21 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-08-01 00:00:00+00:00: TP_lake=142.53 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-09-01 00:00:00+00:00: TP_lake=140.77 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-10-01 00:00:00+00:00: TP_lake=138.84 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-11-01 00:00:00+00:00: TP_lake=136.97 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1986-12-01 00:00:00+00:00: TP_lake=135.33 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-01-01 00:00:00+00:00: TP_lake=121.50 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-02-01 00:00:00+00:00: TP_lake=119.08 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-03-01 00:00:00+00:00: TP_lake=131.26 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-04-01 00:00:00+00:00: TP_lake=131.19 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-05-01 00:00:00+00:00: TP_lake=130.87 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-06-01 00:00:00+00:00: TP_lake=129.64 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-07-01 00:00:00+00:00: TP_lake=131.52 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-08-01 00:00:00+00:00: TP_lake=130.01 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-09-01 00:00:00+00:00: TP_lake=128.28 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-10-01 00:00:00+00:00: TP_lake=128.04 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-11-01 00:00:00+00:00: TP_lake=126.39 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1987-12-01 00:00:00+00:00: TP_lake=125.00 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-01-01 00:00:00+00:00: TP_lake=111.64 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-02-01 00:00:00+00:00: TP_lake=109.31 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-03-01 00:00:00+00:00: TP_lake=107.19 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-04-01 00:00:00+00:00: TP_lake=105.30 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-05-01 00:00:00+00:00: TP_lake=103.19 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-06-01 00:00:00+00:00: TP_lake=108.42 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-07-01 00:00:00+00:00: TP_lake=108.29 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-08-01 00:00:00+00:00: TP_lake=110.04 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-09-01 00:00:00+00:00: TP_lake=108.44 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-10-01 00:00:00+00:00: TP_lake=106.85 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-11-01 00:00:00+00:00: TP_lake=106.08 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1988-12-01 00:00:00+00:00: TP_lake=104.47 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-01-01 00:00:00+00:00: TP_lake=92.71 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-02-01 00:00:00+00:00: TP_lake=90.49 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-03-01 00:00:00+00:00: TP_lake=88.53 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-04-01 00:00:00+00:00: TP_lake=86.44 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-05-01 00:00:00+00:00: TP_lake=84.87 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-06-01 00:00:00+00:00: TP_lake=85.58 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-07-01 00:00:00+00:00: TP_lake=83.84 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-08-01 00:00:00+00:00: TP_lake=84.67 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-09-01 00:00:00+00:00: TP_lake=83.56 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-10-01 00:00:00+00:00: TP_lake=82.58 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-11-01 00:00:00+00:00: TP_lake=81.22 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1989-12-01 00:00:00+00:00: TP_lake=79.74 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-01-01 00:00:00+00:00: TP_lake=70.75 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-02-01 00:00:00+00:00: TP_lake=68.70 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-03-01 00:00:00+00:00: TP_lake=67.25 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-04-01 00:00:00+00:00: TP_lake=65.47 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-05-01 00:00:00+00:00: TP_lake=72.68 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-06-01 00:00:00+00:00: TP_lake=71.80 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-07-01 00:00:00+00:00: TP_lake=73.56 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-08-01 00:00:00+00:00: TP_lake=72.60 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-09-01 00:00:00+00:00: TP_lake=71.72 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-10-01 00:00:00+00:00: TP_lake=70.04 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-11-01 00:00:00+00:00: TP_lake=68.82 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1990-12-01 00:00:00+00:00: TP_lake=69.33 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-01-01 00:00:00+00:00: TP_lake=60.78 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-02-01 00:00:00+00:00: TP_lake=59.42 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-03-01 00:00:00+00:00: TP_lake=57.68 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-04-01 00:00:00+00:00: TP_lake=56.00 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-05-01 00:00:00+00:00: TP_lake=54.26 mg/m3, P_NS=4.73 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-06-01 00:00:00+00:00: TP_lake=59.52 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-07-01 00:00:00+00:00: TP_lake=59.31 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-08-01 00:00:00+00:00: TP_lake=60.94 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-09-01 00:00:00+00:00: TP_lake=59.01 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-10-01 00:00:00+00:00: TP_lake=57.06 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-11-01 00:00:00+00:00: TP_lake=55.09 mg/m3, P_NS=4.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1991-12-01 00:00:00+00:00: TP_lake=54.42 mg/m3, P_NS=4.74 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-01-01 00:00:00+00:00: TP_lake=48.23 mg/m3, P_NS=4.20 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-02-01 00:00:00+00:00: TP_lake=46.62 mg/m3, P_NS=4.06 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-03-01 00:00:00+00:00: TP_lake=37.15 mg/m3, P_NS=3.24 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-04-01 00:00:00+00:00: TP_lake=36.95 mg/m3, P_NS=3.22 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-05-01 00:00:00+00:00: TP_lake=36.51 mg/m3, P_NS=3.18 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-06-01 00:00:00+00:00: TP_lake=39.78 mg/m3, P_NS=3.47 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-07-01 00:00:00+00:00: TP_lake=38.86 mg/m3, P_NS=3.39 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-08-01 00:00:00+00:00: TP_lake=39.65 mg/m3, P_NS=3.46 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-09-01 00:00:00+00:00: TP_lake=39.09 mg/m3, P_NS=3.41 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-10-01 00:00:00+00:00: TP_lake=38.59 mg/m3, P_NS=3.36 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-11-01 00:00:00+00:00: TP_lake=39.35 mg/m3, P_NS=3.43 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1992-12-01 00:00:00+00:00: TP_lake=40.64 mg/m3, P_NS=3.54 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-01-01 00:00:00+00:00: TP_lake=36.96 mg/m3, P_NS=3.22 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-02-01 00:00:00+00:00: TP_lake=36.18 mg/m3, P_NS=3.15 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-03-01 00:00:00+00:00: TP_lake=35.27 mg/m3, P_NS=3.07 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-04-01 00:00:00+00:00: TP_lake=34.55 mg/m3, P_NS=3.01 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-05-01 00:00:00+00:00: TP_lake=36.98 mg/m3, P_NS=3.22 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-06-01 00:00:00+00:00: TP_lake=37.19 mg/m3, P_NS=3.24 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-07-01 00:00:00+00:00: TP_lake=36.85 mg/m3, P_NS=3.21 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-08-01 00:00:00+00:00: TP_lake=38.93 mg/m3, P_NS=3.39 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-09-01 00:00:00+00:00: TP_lake=39.43 mg/m3, P_NS=3.44 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-10-01 00:00:00+00:00: TP_lake=39.27 mg/m3, P_NS=3.42 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-11-01 00:00:00+00:00: TP_lake=39.46 mg/m3, P_NS=3.44 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1993-12-01 00:00:00+00:00: TP_lake=39.24 mg/m3, P_NS=3.42 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-01-01 00:00:00+00:00: TP_lake=35.49 mg/m3, P_NS=3.09 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-02-01 00:00:00+00:00: TP_lake=36.03 mg/m3, P_NS=3.14 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-03-01 00:00:00+00:00: TP_lake=35.58 mg/m3, P_NS=3.10 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-04-01 00:00:00+00:00: TP_lake=34.99 mg/m3, P_NS=3.05 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-05-01 00:00:00+00:00: TP_lake=39.78 mg/m3, P_NS=3.47 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-06-01 00:00:00+00:00: TP_lake=42.72 mg/m3, P_NS=3.72 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-07-01 00:00:00+00:00: TP_lake=45.69 mg/m3, P_NS=3.98 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-08-01 00:00:00+00:00: TP_lake=44.65 mg/m3, P_NS=3.89 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-09-01 00:00:00+00:00: TP_lake=43.78 mg/m3, P_NS=3.82 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-10-01 00:00:00+00:00: TP_lake=43.51 mg/m3, P_NS=3.79 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-11-01 00:00:00+00:00: TP_lake=43.51 mg/m3, P_NS=3.79 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1994-12-01 00:00:00+00:00: TP_lake=42.94 mg/m3, P_NS=3.74 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-01-01 00:00:00+00:00: TP_lake=39.79 mg/m3, P_NS=3.47 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-02-01 00:00:00+00:00: TP_lake=40.14 mg/m3, P_NS=3.50 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-03-01 00:00:00+00:00: TP_lake=39.91 mg/m3, P_NS=3.48 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-04-01 00:00:00+00:00: TP_lake=39.66 mg/m3, P_NS=3.46 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-05-01 00:00:00+00:00: TP_lake=39.01 mg/m3, P_NS=3.40 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-06-01 00:00:00+00:00: TP_lake=42.50 mg/m3, P_NS=3.70 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-07-01 00:00:00+00:00: TP_lake=43.81 mg/m3, P_NS=3.82 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-08-01 00:00:00+00:00: TP_lake=45.32 mg/m3, P_NS=3.95 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-09-01 00:00:00+00:00: TP_lake=44.60 mg/m3, P_NS=3.89 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-10-01 00:00:00+00:00: TP_lake=44.45 mg/m3, P_NS=3.87 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-11-01 00:00:00+00:00: TP_lake=43.13 mg/m3, P_NS=3.76 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1995-12-01 00:00:00+00:00: TP_lake=42.20 mg/m3, P_NS=3.68 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-01-01 00:00:00+00:00: TP_lake=38.98 mg/m3, P_NS=3.40 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-02-01 00:00:00+00:00: TP_lake=38.14 mg/m3, P_NS=3.32 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-03-01 00:00:00+00:00: TP_lake=36.79 mg/m3, P_NS=3.21 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-04-01 00:00:00+00:00: TP_lake=35.37 mg/m3, P_NS=3.08 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-05-01 00:00:00+00:00: TP_lake=34.00 mg/m3, P_NS=2.96 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-06-01 00:00:00+00:00: TP_lake=37.52 mg/m3, P_NS=3.27 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-07-01 00:00:00+00:00: TP_lake=36.61 mg/m3, P_NS=3.19 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-08-01 00:00:00+00:00: TP_lake=37.69 mg/m3, P_NS=3.28 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-09-01 00:00:00+00:00: TP_lake=36.58 mg/m3, P_NS=3.19 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-10-01 00:00:00+00:00: TP_lake=35.24 mg/m3, P_NS=3.07 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-11-01 00:00:00+00:00: TP_lake=34.56 mg/m3, P_NS=3.01 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1996-12-01 00:00:00+00:00: TP_lake=34.35 mg/m3, P_NS=2.99 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-01-01 00:00:00+00:00: TP_lake=30.21 mg/m3, P_NS=2.63 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-02-01 00:00:00+00:00: TP_lake=29.10 mg/m3, P_NS=2.54 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-03-01 00:00:00+00:00: TP_lake=28.30 mg/m3, P_NS=2.47 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-04-01 00:00:00+00:00: TP_lake=27.22 mg/m3, P_NS=2.37 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-05-01 00:00:00+00:00: TP_lake=28.72 mg/m3, P_NS=2.50 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-06-01 00:00:00+00:00: TP_lake=28.71 mg/m3, P_NS=2.50 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-07-01 00:00:00+00:00: TP_lake=28.27 mg/m3, P_NS=2.46 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-08-01 00:00:00+00:00: TP_lake=29.28 mg/m3, P_NS=2.55 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-09-01 00:00:00+00:00: TP_lake=28.68 mg/m3, P_NS=2.50 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-10-01 00:00:00+00:00: TP_lake=27.72 mg/m3, P_NS=2.42 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-11-01 00:00:00+00:00: TP_lake=26.61 mg/m3, P_NS=2.32 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1997-12-01 00:00:00+00:00: TP_lake=25.59 mg/m3, P_NS=2.23 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-01-01 00:00:00+00:00: TP_lake=23.10 mg/m3, P_NS=2.01 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-02-01 00:00:00+00:00: TP_lake=22.41 mg/m3, P_NS=1.95 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-03-01 00:00:00+00:00: TP_lake=21.68 mg/m3, P_NS=1.89 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-04-01 00:00:00+00:00: TP_lake=21.15 mg/m3, P_NS=1.84 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-05-01 00:00:00+00:00: TP_lake=23.70 mg/m3, P_NS=2.07 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-06-01 00:00:00+00:00: TP_lake=22.91 mg/m3, P_NS=2.00 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-07-01 00:00:00+00:00: TP_lake=22.13 mg/m3, P_NS=1.93 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-08-01 00:00:00+00:00: TP_lake=22.12 mg/m3, P_NS=1.93 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-09-01 00:00:00+00:00: TP_lake=21.26 mg/m3, P_NS=1.85 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-10-01 00:00:00+00:00: TP_lake=21.58 mg/m3, P_NS=1.88 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-11-01 00:00:00+00:00: TP_lake=22.82 mg/m3, P_NS=1.99 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1998-12-01 00:00:00+00:00: TP_lake=25.33 mg/m3, P_NS=2.21 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-01-01 00:00:00+00:00: TP_lake=22.47 mg/m3, P_NS=1.96 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-02-01 00:00:00+00:00: TP_lake=22.39 mg/m3, P_NS=1.95 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-03-01 00:00:00+00:00: TP_lake=28.19 mg/m3, P_NS=2.46 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-04-01 00:00:00+00:00: TP_lake=28.29 mg/m3, P_NS=2.47 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-05-01 00:00:00+00:00: TP_lake=27.75 mg/m3, P_NS=2.42 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-06-01 00:00:00+00:00: TP_lake=32.02 mg/m3, P_NS=2.79 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-07-01 00:00:00+00:00: TP_lake=31.91 mg/m3, P_NS=2.78 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-08-01 00:00:00+00:00: TP_lake=32.66 mg/m3, P_NS=2.85 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-09-01 00:00:00+00:00: TP_lake=33.11 mg/m3, P_NS=2.89 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-10-01 00:00:00+00:00: TP_lake=32.62 mg/m3, P_NS=2.84 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-11-01 00:00:00+00:00: TP_lake=31.83 mg/m3, P_NS=2.77 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 1999-12-01 00:00:00+00:00: TP_lake=31.68 mg/m3, P_NS=2.76 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-01-01 00:00:00+00:00: TP_lake=29.20 mg/m3, P_NS=2.55 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-02-01 00:00:00+00:00: TP_lake=28.48 mg/m3, P_NS=2.48 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-03-01 00:00:00+00:00: TP_lake=28.75 mg/m3, P_NS=2.51 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-04-01 00:00:00+00:00: TP_lake=28.20 mg/m3, P_NS=2.46 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-05-01 00:00:00+00:00: TP_lake=30.75 mg/m3, P_NS=2.68 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-06-01 00:00:00+00:00: TP_lake=29.77 mg/m3, P_NS=2.59 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-07-01 00:00:00+00:00: TP_lake=30.22 mg/m3, P_NS=2.63 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-08-01 00:00:00+00:00: TP_lake=31.00 mg/m3, P_NS=2.70 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-09-01 00:00:00+00:00: TP_lake=31.60 mg/m3, P_NS=2.75 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-10-01 00:00:00+00:00: TP_lake=31.44 mg/m3, P_NS=2.74 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-11-01 00:00:00+00:00: TP_lake=30.77 mg/m3, P_NS=2.68 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2000-12-01 00:00:00+00:00: TP_lake=30.36 mg/m3, P_NS=2.65 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-01-01 00:00:00+00:00: TP_lake=29.33 mg/m3, P_NS=2.56 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-02-01 00:00:00+00:00: TP_lake=27.57 mg/m3, P_NS=2.40 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-03-01 00:00:00+00:00: TP_lake=26.61 mg/m3, P_NS=2.32 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-04-01 00:00:00+00:00: TP_lake=29.19 mg/m3, P_NS=2.54 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-05-01 00:00:00+00:00: TP_lake=32.24 mg/m3, P_NS=2.81 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-06-01 00:00:00+00:00: TP_lake=32.23 mg/m3, P_NS=2.81 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-07-01 00:00:00+00:00: TP_lake=34.65 mg/m3, P_NS=3.02 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-08-01 00:00:00+00:00: TP_lake=36.99 mg/m3, P_NS=3.22 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-09-01 00:00:00+00:00: TP_lake=36.04 mg/m3, P_NS=3.14 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-10-01 00:00:00+00:00: TP_lake=36.86 mg/m3, P_NS=3.21 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-11-01 00:00:00+00:00: TP_lake=35.69 mg/m3, P_NS=3.11 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2001-12-01 00:00:00+00:00: TP_lake=35.18 mg/m3, P_NS=3.07 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-01-01 00:00:00+00:00: TP_lake=29.98 mg/m3, P_NS=2.61 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-02-01 00:00:00+00:00: TP_lake=28.87 mg/m3, P_NS=2.52 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-03-01 00:00:00+00:00: TP_lake=28.33 mg/m3, P_NS=2.47 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-04-01 00:00:00+00:00: TP_lake=27.82 mg/m3, P_NS=2.42 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-05-01 00:00:00+00:00: TP_lake=31.27 mg/m3, P_NS=2.73 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-06-01 00:00:00+00:00: TP_lake=31.55 mg/m3, P_NS=2.75 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-07-01 00:00:00+00:00: TP_lake=32.21 mg/m3, P_NS=2.81 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-08-01 00:00:00+00:00: TP_lake=32.52 mg/m3, P_NS=2.83 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-09-01 00:00:00+00:00: TP_lake=32.19 mg/m3, P_NS=2.81 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-10-01 00:00:00+00:00: TP_lake=33.37 mg/m3, P_NS=2.91 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-11-01 00:00:00+00:00: TP_lake=33.76 mg/m3, P_NS=2.94 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2002-12-01 00:00:00+00:00: TP_lake=36.68 mg/m3, P_NS=3.20 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-01-01 00:00:00+00:00: TP_lake=32.01 mg/m3, P_NS=2.79 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-02-01 00:00:00+00:00: TP_lake=31.20 mg/m3, P_NS=2.72 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-03-01 00:00:00+00:00: TP_lake=30.30 mg/m3, P_NS=2.64 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-04-01 00:00:00+00:00: TP_lake=29.50 mg/m3, P_NS=2.57 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-05-01 00:00:00+00:00: TP_lake=32.95 mg/m3, P_NS=2.87 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-06-01 00:00:00+00:00: TP_lake=31.99 mg/m3, P_NS=2.79 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-07-01 00:00:00+00:00: TP_lake=32.66 mg/m3, P_NS=2.85 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-08-01 00:00:00+00:00: TP_lake=31.54 mg/m3, P_NS=2.75 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-09-01 00:00:00+00:00: TP_lake=30.81 mg/m3, P_NS=2.69 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-10-01 00:00:00+00:00: TP_lake=29.63 mg/m3, P_NS=2.58 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-11-01 00:00:00+00:00: TP_lake=29.38 mg/m3, P_NS=2.56 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2003-12-01 00:00:00+00:00: TP_lake=28.96 mg/m3, P_NS=2.52 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-01-01 00:00:00+00:00: TP_lake=25.70 mg/m3, P_NS=2.24 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-02-01 00:00:00+00:00: TP_lake=26.89 mg/m3, P_NS=2.34 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-03-01 00:00:00+00:00: TP_lake=26.18 mg/m3, P_NS=2.28 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-04-01 00:00:00+00:00: TP_lake=25.49 mg/m3, P_NS=2.22 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-05-01 00:00:00+00:00: TP_lake=28.30 mg/m3, P_NS=2.47 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-06-01 00:00:00+00:00: TP_lake=28.06 mg/m3, P_NS=2.45 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-07-01 00:00:00+00:00: TP_lake=29.68 mg/m3, P_NS=2.59 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-08-01 00:00:00+00:00: TP_lake=30.23 mg/m3, P_NS=2.64 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-09-01 00:00:00+00:00: TP_lake=29.35 mg/m3, P_NS=2.56 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-10-01 00:00:00+00:00: TP_lake=28.25 mg/m3, P_NS=2.46 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-11-01 00:00:00+00:00: TP_lake=27.57 mg/m3, P_NS=2.40 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2004-12-01 00:00:00+00:00: TP_lake=26.52 mg/m3, P_NS=2.31 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-01-01 00:00:00+00:00: TP_lake=23.18 mg/m3, P_NS=2.02 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-02-01 00:00:00+00:00: TP_lake=22.45 mg/m3, P_NS=1.96 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-03-01 00:00:00+00:00: TP_lake=22.06 mg/m3, P_NS=1.92 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-04-01 00:00:00+00:00: TP_lake=23.90 mg/m3, P_NS=2.08 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-05-01 00:00:00+00:00: TP_lake=25.07 mg/m3, P_NS=2.18 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-06-01 00:00:00+00:00: TP_lake=26.52 mg/m3, P_NS=2.31 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-07-01 00:00:00+00:00: TP_lake=25.72 mg/m3, P_NS=2.24 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-08-01 00:00:00+00:00: TP_lake=25.02 mg/m3, P_NS=2.18 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-09-01 00:00:00+00:00: TP_lake=31.41 mg/m3, P_NS=2.74 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-10-01 00:00:00+00:00: TP_lake=30.75 mg/m3, P_NS=2.68 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-11-01 00:00:00+00:00: TP_lake=30.35 mg/m3, P_NS=2.65 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2005-12-01 00:00:00+00:00: TP_lake=29.26 mg/m3, P_NS=2.55 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-01-01 00:00:00+00:00: TP_lake=25.40 mg/m3, P_NS=2.21 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-02-01 00:00:00+00:00: TP_lake=24.74 mg/m3, P_NS=2.16 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-03-01 00:00:00+00:00: TP_lake=18.25 mg/m3, P_NS=1.59 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-04-01 00:00:00+00:00: TP_lake=19.37 mg/m3, P_NS=1.69 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-05-01 00:00:00+00:00: TP_lake=21.41 mg/m3, P_NS=1.87 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-06-01 00:00:00+00:00: TP_lake=25.26 mg/m3, P_NS=2.20 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-07-01 00:00:00+00:00: TP_lake=25.25 mg/m3, P_NS=2.20 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-08-01 00:00:00+00:00: TP_lake=24.39 mg/m3, P_NS=2.13 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-09-01 00:00:00+00:00: TP_lake=24.44 mg/m3, P_NS=2.13 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-10-01 00:00:00+00:00: TP_lake=24.61 mg/m3, P_NS=2.14 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-11-01 00:00:00+00:00: TP_lake=24.39 mg/m3, P_NS=2.13 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2006-12-01 00:00:00+00:00: TP_lake=23.51 mg/m3, P_NS=2.05 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-01-01 00:00:00+00:00: TP_lake=21.25 mg/m3, P_NS=1.85 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-02-01 00:00:00+00:00: TP_lake=20.67 mg/m3, P_NS=1.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-03-01 00:00:00+00:00: TP_lake=20.44 mg/m3, P_NS=1.78 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-04-01 00:00:00+00:00: TP_lake=20.85 mg/m3, P_NS=1.82 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-05-01 00:00:00+00:00: TP_lake=23.65 mg/m3, P_NS=2.06 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-06-01 00:00:00+00:00: TP_lake=24.08 mg/m3, P_NS=2.10 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-07-01 00:00:00+00:00: TP_lake=24.92 mg/m3, P_NS=2.17 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-08-01 00:00:00+00:00: TP_lake=26.76 mg/m3, P_NS=2.33 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-09-01 00:00:00+00:00: TP_lake=31.75 mg/m3, P_NS=2.77 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-10-01 00:00:00+00:00: TP_lake=30.77 mg/m3, P_NS=2.68 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-11-01 00:00:00+00:00: TP_lake=29.74 mg/m3, P_NS=2.59 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2007-12-01 00:00:00+00:00: TP_lake=28.85 mg/m3, P_NS=2.51 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-01-01 00:00:00+00:00: TP_lake=25.18 mg/m3, P_NS=2.19 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-02-01 00:00:00+00:00: TP_lake=24.54 mg/m3, P_NS=2.14 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-03-01 00:00:00+00:00: TP_lake=23.77 mg/m3, P_NS=2.07 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-04-01 00:00:00+00:00: TP_lake=23.31 mg/m3, P_NS=2.03 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-05-01 00:00:00+00:00: TP_lake=26.30 mg/m3, P_NS=2.29 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-06-01 00:00:00+00:00: TP_lake=25.48 mg/m3, P_NS=2.22 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-07-01 00:00:00+00:00: TP_lake=25.41 mg/m3, P_NS=2.21 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-08-01 00:00:00+00:00: TP_lake=25.04 mg/m3, P_NS=2.18 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-09-01 00:00:00+00:00: TP_lake=24.88 mg/m3, P_NS=2.17 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-10-01 00:00:00+00:00: TP_lake=26.08 mg/m3, P_NS=2.27 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-11-01 00:00:00+00:00: TP_lake=25.50 mg/m3, P_NS=2.22 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2008-12-01 00:00:00+00:00: TP_lake=25.26 mg/m3, P_NS=2.20 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-01-01 00:00:00+00:00: TP_lake=22.15 mg/m3, P_NS=1.93 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-02-01 00:00:00+00:00: TP_lake=21.94 mg/m3, P_NS=1.91 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-03-01 00:00:00+00:00: TP_lake=21.62 mg/m3, P_NS=1.88 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-04-01 00:00:00+00:00: TP_lake=22.27 mg/m3, P_NS=1.94 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-05-01 00:00:00+00:00: TP_lake=21.51 mg/m3, P_NS=1.87 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-06-01 00:00:00+00:00: TP_lake=23.65 mg/m3, P_NS=2.06 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-07-01 00:00:00+00:00: TP_lake=23.55 mg/m3, P_NS=2.05 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-08-01 00:00:00+00:00: TP_lake=24.47 mg/m3, P_NS=2.13 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-09-01 00:00:00+00:00: TP_lake=24.16 mg/m3, P_NS=2.11 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-10-01 00:00:00+00:00: TP_lake=23.26 mg/m3, P_NS=2.03 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-11-01 00:00:00+00:00: TP_lake=22.37 mg/m3, P_NS=1.95 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2009-12-01 00:00:00+00:00: TP_lake=21.98 mg/m3, P_NS=1.92 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-01-01 00:00:00+00:00: TP_lake=21.13 mg/m3, P_NS=1.84 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-02-01 00:00:00+00:00: TP_lake=20.58 mg/m3, P_NS=1.79 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-03-01 00:00:00+00:00: TP_lake=16.01 mg/m3, P_NS=1.40 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-04-01 00:00:00+00:00: TP_lake=15.44 mg/m3, P_NS=1.35 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-05-01 00:00:00+00:00: TP_lake=14.89 mg/m3, P_NS=1.30 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-06-01 00:00:00+00:00: TP_lake=16.59 mg/m3, P_NS=1.45 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-07-01 00:00:00+00:00: TP_lake=18.57 mg/m3, P_NS=1.62 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-08-01 00:00:00+00:00: TP_lake=20.36 mg/m3, P_NS=1.77 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-09-01 00:00:00+00:00: TP_lake=20.86 mg/m3, P_NS=1.82 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-10-01 00:00:00+00:00: TP_lake=20.88 mg/m3, P_NS=1.82 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-11-01 00:00:00+00:00: TP_lake=20.92 mg/m3, P_NS=1.82 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2010-12-01 00:00:00+00:00: TP_lake=20.70 mg/m3, P_NS=1.80 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-01-01 00:00:00+00:00: TP_lake=19.21 mg/m3, P_NS=1.67 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-02-01 00:00:00+00:00: TP_lake=19.46 mg/m3, P_NS=1.70 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-03-01 00:00:00+00:00: TP_lake=18.99 mg/m3, P_NS=1.66 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-04-01 00:00:00+00:00: TP_lake=18.38 mg/m3, P_NS=1.60 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-05-01 00:00:00+00:00: TP_lake=19.93 mg/m3, P_NS=1.74 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-06-01 00:00:00+00:00: TP_lake=19.25 mg/m3, P_NS=1.68 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-07-01 00:00:00+00:00: TP_lake=19.24 mg/m3, P_NS=1.68 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-08-01 00:00:00+00:00: TP_lake=21.05 mg/m3, P_NS=1.84 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-09-01 00:00:00+00:00: TP_lake=21.98 mg/m3, P_NS=1.92 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-10-01 00:00:00+00:00: TP_lake=21.50 mg/m3, P_NS=1.87 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-11-01 00:00:00+00:00: TP_lake=21.12 mg/m3, P_NS=1.84 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2011-12-01 00:00:00+00:00: TP_lake=20.30 mg/m3, P_NS=1.77 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-01-01 00:00:00+00:00: TP_lake=19.69 mg/m3, P_NS=1.72 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-02-01 00:00:00+00:00: TP_lake=20.46 mg/m3, P_NS=1.78 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-03-01 00:00:00+00:00: TP_lake=19.91 mg/m3, P_NS=1.74 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-04-01 00:00:00+00:00: TP_lake=19.27 mg/m3, P_NS=1.68 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-05-01 00:00:00+00:00: TP_lake=21.16 mg/m3, P_NS=1.84 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-06-01 00:00:00+00:00: TP_lake=21.15 mg/m3, P_NS=1.84 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-07-01 00:00:00+00:00: TP_lake=21.93 mg/m3, P_NS=1.91 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-08-01 00:00:00+00:00: TP_lake=22.16 mg/m3, P_NS=1.93 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-09-01 00:00:00+00:00: TP_lake=22.15 mg/m3, P_NS=1.93 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-10-01 00:00:00+00:00: TP_lake=22.72 mg/m3, P_NS=1.98 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-11-01 00:00:00+00:00: TP_lake=23.66 mg/m3, P_NS=2.06 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2012-12-01 00:00:00+00:00: TP_lake=24.44 mg/m3, P_NS=2.13 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-01-01 00:00:00+00:00: TP_lake=24.14 mg/m3, P_NS=2.10 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-02-01 00:00:00+00:00: TP_lake=23.87 mg/m3, P_NS=2.08 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-03-01 00:00:00+00:00: TP_lake=24.26 mg/m3, P_NS=2.11 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-04-01 00:00:00+00:00: TP_lake=23.63 mg/m3, P_NS=2.06 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-05-01 00:00:00+00:00: TP_lake=23.87 mg/m3, P_NS=2.08 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-06-01 00:00:00+00:00: TP_lake=26.17 mg/m3, P_NS=2.28 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-07-01 00:00:00+00:00: TP_lake=27.89 mg/m3, P_NS=2.43 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-08-01 00:00:00+00:00: TP_lake=29.07 mg/m3, P_NS=2.53 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-09-01 00:00:00+00:00: TP_lake=28.07 mg/m3, P_NS=2.45 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-10-01 00:00:00+00:00: TP_lake=27.11 mg/m3, P_NS=2.36 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-11-01 00:00:00+00:00: TP_lake=26.57 mg/m3, P_NS=2.32 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2013-12-01 00:00:00+00:00: TP_lake=27.15 mg/m3, P_NS=2.37 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-01-01 00:00:00+00:00: TP_lake=23.00 mg/m3, P_NS=2.01 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-02-01 00:00:00+00:00: TP_lake=22.57 mg/m3, P_NS=1.97 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-03-01 00:00:00+00:00: TP_lake=22.26 mg/m3, P_NS=1.94 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-04-01 00:00:00+00:00: TP_lake=21.48 mg/m3, P_NS=1.87 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-05-01 00:00:00+00:00: TP_lake=22.35 mg/m3, P_NS=1.95 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-06-01 00:00:00+00:00: TP_lake=22.34 mg/m3, P_NS=1.95 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-07-01 00:00:00+00:00: TP_lake=21.56 mg/m3, P_NS=1.88 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-08-01 00:00:00+00:00: TP_lake=24.18 mg/m3, P_NS=2.11 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-09-01 00:00:00+00:00: TP_lake=25.08 mg/m3, P_NS=2.19 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-10-01 00:00:00+00:00: TP_lake=25.12 mg/m3, P_NS=2.19 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-11-01 00:00:00+00:00: TP_lake=25.28 mg/m3, P_NS=2.20 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2014-12-01 00:00:00+00:00: TP_lake=25.96 mg/m3, P_NS=2.26 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-01-01 00:00:00+00:00: TP_lake=25.06 mg/m3, P_NS=2.18 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-02-01 00:00:00+00:00: TP_lake=22.99 mg/m3, P_NS=2.00 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-03-01 00:00:00+00:00: TP_lake=22.78 mg/m3, P_NS=1.99 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-04-01 00:00:00+00:00: TP_lake=22.61 mg/m3, P_NS=1.97 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-05-01 00:00:00+00:00: TP_lake=24.05 mg/m3, P_NS=2.10 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-06-01 00:00:00+00:00: TP_lake=29.27 mg/m3, P_NS=2.55 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-07-01 00:00:00+00:00: TP_lake=32.21 mg/m3, P_NS=2.81 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-08-01 00:00:00+00:00: TP_lake=30.98 mg/m3, P_NS=2.70 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-09-01 00:00:00+00:00: TP_lake=30.46 mg/m3, P_NS=2.65 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-10-01 00:00:00+00:00: TP_lake=29.26 mg/m3, P_NS=2.55 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3
# 2015-11-01 00:00:00+00:00: TP_lake=28.07 mg/m3, P_NS=2.45 tons/yr, sigma_max=0.50 yr-1, TPcrit=55.07 mg/m3

# %%
# Load data from Müller et al. (2012)
#df_Muller_obs=pd.read_excel(r"C:\Users\tdoda\OneDrive - Université de Lausanne\External drive\Data\Phosphorus\Baldeggersee_Muller\table2_paper_2012.xlsx",sheet_name="Obs",skiprows=[1,2],
#                       parse_dates=["Jahr"])
df_Muller_model=pd.read_excel(r"C:\Users\tdoda\OneDrive - Université de Lausanne\External drive\Data\Phosphorus\Baldeggersee_Muller\table2_paper_2012.xlsx",sheet_name="Model",skiprows=np.concatenate((np.arange(0,4),np.array([5,6]))),
                       parse_dates=["Jahr"])

# %%
fig,ax=plt.subplots(3,1,figsize=(8,6),sharex=True)
colplots=plt.get_cmap('tab10')
col_yellow=(1,190/255,0)
col_orange=(240/255,125/255,50/255)
tdate_predict=np.array([datetime.fromtimestamp(tnum,UTC) for tnum in tnum_predict])

ax[0].plot(tdate_budget,P_fluxes["Pin"],'-',color=colplots(0))
ax[0].plot(tdate_budget,P_fluxes["Pout_epi"],'-',color=colplots(2))
ax[0].plot(tdate_budget,P_fluxes["Pz"],'-',color='m')
ax[0].plot(tdate_budget,P_fluxes["Premob"]+P_fluxes["Pnet_sed"],'-',color=col_yellow)
ax[0].plot(tdate_budget,P_fluxes["Pnet_sed"],'-',color=col_orange)
ax[0].plot(tdate_budget,P_fluxes["Premob"],'-',color='r')
ax[0].set_ylabel('$P$ [tons-P/yr]')
ax[0].legend(["$P_{\\rm in}$","$P_{\\rm out}$","$P_{z}$","$P_{\\rm GrossSed}$","$P_{\\rm NetSed}$","$P_{\\rm remob}$"])

p1,=ax[1].plot(tdate_predict,TPepi_predict,'--',color='orange')
# ax[1].fill_between(np.concatenate((tdate_predict,np.flip(tdate_predict))),np.concatenate((TPepi_range[0,:],np.flip(TPepi_range[1,:]))),\
#                    facecolor='orange',edgecolor=None,alpha=0.2)
p2,=ax[1].plot(tdate_compare,TPepi_compare,'.',color='orange',markersize=5)
p3,=ax[1].plot(tdate_predict,TPhypo_predict,'--',color=(0.8,0,0))
# ax[1].fill_between(np.concatenate((tdate_predict,np.flip(tdate_predict))),np.concatenate((TPhypo_range[0,:],np.flip(TPhypo_range[1,:]))),\
#                    facecolor=(0.8,0,0),edgecolor=None,alpha=0.2)
p4,=ax[1].plot(tdate_compare,TPhypo_compare,'.',color=(0.8,0,0),markersize=5)
ax[1].set_ylabel('$TP$ [mg-P/m$^3$]')
ax[1].legend([p1,p2,p3,p4],["$TP_{\\rm epi,mod}$","$TP_{\\rm epi,obs}$","$TP_{\\rm hypo,mod}$","$TP_{\\rm hypo,obs}$"])

TPlake_obs=np.nanmean(np.array([TPepi_compare,TPhypo_compare]),axis=0)
TPlake_mod=np.nanmean(np.array([TPepi_predict,TPhypo_predict]),axis=0)
# Define the mixing period from 1st Feb
ind_mod=[np.argmin(np.abs(tdate_predict-dt.replace(tzinfo=timezone.utc))) for dt in df_Muller_model["Jahr"].values.astype("datetime64[s]").astype(datetime)+timedelta(days=31)]
ind_obs=[np.argmin(np.abs(tdate_compare-dt)) for dt in df_Muller_model["Jahr"].values.astype("datetime64[s]").astype(datetime)+timedelta(days=31)]
p1,=ax[2].plot(tdate_predict[ind_mod],TPlake_mod[ind_mod],'o--',color=(0.8,0,0))
p2,=ax[2].plot(tdate_compare[ind_obs],TPlake_obs[ind_obs],'ko-')
p3,=ax[2].plot(df_Muller_model["Jahr"].values,df_Muller_model["TPmod"].values,'o--',color=(0,0,0.8))
ax[2].set_ylabel('$TP_{\\rm mixed}$ [mg-P/m$^3$]')
ax[2].legend([p1,p2,p3],["$TP_{\\rm mixed,mod}$","$TP_{\\rm mixed,obs}$","$TP_{\\rm mixed,Müller}$"])

fig.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Save figure
if savefig_bool:
    fig.savefig("../Figures/TP_predict_long_"+method_Pin+".png",dpi=400)
    fig.savefig("../Figures/TP_predict__long"+method_Pin+".svg")
    print('Figure saved!')

# %%
# Compare Pin between model and Müller:
df_P=pd.DataFrame({"Date":tdate_budget,"Year":np.array([dt.year for dt in tdate_budget]),"Pin":P_fluxes["Pin"]})
df_P2=df_P.groupby("Year").mean()
plt.figure()
plt.plot(df_P2["Date"].values,df_P2["Pin"].values,'o-')
plt.plot(df_Muller_model["Jahr"].values,df_Muller_model["AVPin_mod"].values/1000,'ko-')
plt.legend(["Model","Müller"])
plt.ylabel("Pin [tons-P/yr]")
# Out:
# Text(0, 0.5, 'Pin [tons-P/yr]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Export concentrations
df_mod=pd.DataFrame({"tdate":[tdate.strftime("%Y%m%d") for tdate in tdate_predict],"TPepi":TPepi_predict,"TPhypo":TPhypo_predict,"TPlake":TPlake_mod})
df_mod.to_csv("results_model_"+tdate_min_max[0].strftime("%Y")+"_"+tdate_min_max[-1].strftime("%Y")+".csv",sep=",",header=True)
print("Data saved")
# Out:
# Data saved

# %%
plt.figure(figsize=(8,4))
p1,=plt.plot(tdate_predict,TPepi_predict,'--',color='orange')
p2,=plt.plot(tdate_TP,TPepi,'.',color='orange',markersize=5)
p3,=plt.plot(tdate_predict,TPhypo_predict,'--',color=(0.8,0,0))
p4,=plt.plot(tdate_TP,TPhypo,'.',color=(0.8,0,0),markersize=5)

df_mod_entire=pd.read_csv("results_model_1985_2015.csv",parse_dates=["tdate"])
tnum_entire=df_mod_entire["tdate"].values.astype("datetime64[s]").astype(np.int64)
valkeep=tnum_entire<datetime(2000,1,1).timestamp()
plt.plot(df_mod_entire["tdate"].values[valkeep],df_mod_entire["TPepi"].values[valkeep],'--',color='orange')
plt.plot(df_mod_entire["tdate"].values[valkeep],df_mod_entire["TPhypo"].values[valkeep],'--',color=(0.8,0,0))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 4. Sensitivity analysis

# %%
param_name="Pin"
param_units=""
param_factor=np.concatenate((np.array([1]),10.0**(np.linspace(-1,1,10))))
param_factor=np.sort(param_factor)
paramval,TPepi_sens,TPhypo_sens,TPlake_sens=sensitivity_model(param_name,param_factor,tnum_budget,bool_anox,Pin,Qout_budget,hepi_budget,TPepi_0,TPhypo_0,TPsed,
                                                              z_hypso,A_hypso,T_hypo_budget,T_epi_budget,sigma_max=sigma_max,P_NS_max=P_NS_max,TPcrit=TPcrit,
                     method_sed=method_netsed,method_remob="Nurnberg",cst_input=False,show_output=False)
change_TPavg={"Epi":np.nanmean(TPepi_sens,axis=1)/np.nanmean(TPepi_sens[param_factor==1,:],axis=1),
"Hypo":np.nanmean(TPhypo_sens,axis=1)/np.nanmean(TPhypo_sens[param_factor==1,:],axis=1),
"Lake":np.nanmean(TPlake_sens,axis=1)/np.nanmean(TPlake_sens[param_factor==1,:],axis=1)}

change_TPstd={"Epi":np.nanstd(TPepi_sens,axis=1)/np.nanstd(TPepi_sens[param_factor==1,:],axis=1),
"Hypo":np.nanstd(TPhypo_sens,axis=1)/np.nanstd(TPhypo_sens[param_factor==1,:],axis=1),
"Lake":np.nanstd(TPlake_sens,axis=1)/np.nanstd(TPlake_sens[param_factor==1,:],axis=1)}

p=np.polyfit(tnum_budget,TPepi_sens[0,:],1)


change_TPtrend={"Epi":np.array([np.polyfit(tnum_budget,TPepi_sens[k,:],1)[0] for k in range(len(param_factor))])/np.polyfit(tnum_budget,TPepi_sens[np.where(param_factor==1)[0][0],:],1)[0],
"Hypo":np.array([np.polyfit(tnum_budget,TPhypo_sens[k,:],1)[0] for k in range(len(param_factor))])/np.polyfit(tnum_budget,TPhypo_sens[np.where(param_factor==1)[0][0],:],1)[0],
"Lake":np.array([np.polyfit(tnum_budget,TPlake_sens[k,:],1)[0] for k in range(len(param_factor))])/np.polyfit(tnum_budget,TPlake_sens[np.where(param_factor==1)[0][0],:],1)[0]}
# Out:
# Iteration 1/11
# Pin=0.5674220065789461, sigma_max=0.5, PNSmax=4.8
# Iteration 2/11
# Pin=0.9465169539934752, sigma_max=0.5, PNSmax=4.8
# Iteration 3/11
# Pin=1.5788854394254792, sigma_max=0.5, PNSmax=4.8
# Iteration 4/11
# Pin=2.633739649682993, sigma_max=0.5, PNSmax=4.8
# Iteration 5/11
# Pin=4.3933425244812945, sigma_max=0.5, PNSmax=4.8
# Iteration 6/11
# Pin=5.674220065789461, sigma_max=0.5, PNSmax=4.8
# Iteration 7/11
# Pin=7.328537025191112, sigma_max=0.5, PNSmax=4.8
# Iteration 8/11
# Pin=12.22473654861181, sigma_max=0.5, PNSmax=4.8
# Iteration 9/11
# Pin=20.39208960386855, sigma_max=0.5, PNSmax=4.8
# Iteration 10/11
# Pin=34.01605562284486, sigma_max=0.5, PNSmax=4.8
# Iteration 11/11
# Pin=56.742200657894614, sigma_max=0.5, PNSmax=4.8

# %%
# Plot for a given parameter value
k_iteration=0

fig,ax=plt.subplots(2,1,figsize=(8,6),sharex=True)
colplots=plt.get_cmap('tab10')
tdate_predict=np.array([datetime.fromtimestamp(tnum,UTC) for tnum in tnum_budget])
TPepi_predict=TPepi_sens[k_iteration,:]
TPhypo_predict=TPhypo_sens[k_iteration,:]
TPlake_predict=TPlake_sens[k_iteration,:]
TPlake_nochange=TPlake_sens[np.where(param_factor==1)[0][0],:]

p1,=ax[0].plot(tdate_predict,TPepi_predict,'--',color='orange')
p2,=ax[0].plot(tdate_compare,TPepi_compare,'.',color='orange',markersize=5)
p3,=ax[0].plot(tdate_predict,TPhypo_predict,'--',color=(0.8,0,0))
p4,=ax[0].plot(tdate_compare,TPhypo_compare,'.',color=(0.8,0,0),markersize=5)
ax[0].set_ylabel('$TP$ [mg-P/m$^3$]')
ax[0].legend([p1,p2,p3,p4],["$TP_{\\rm epi,mod}$","$TP_{\\rm epi,obs}$","$TP_{\\rm hypo,mod}$","$TP_{\\rm hypo,obs}$"])


# Define the mixing period from 1st Feb
ind_mod=[np.argmin(np.abs(tdate_predict-dt.replace(tzinfo=timezone.utc))) for dt in df_Muller_model["Jahr"].values.astype("datetime64[s]").astype(datetime)+timedelta(days=31)]
p1,=ax[1].plot(tdate_predict[ind_mod],TPlake_predict[ind_mod],'o--',color=(0.8,0,0))
p2,=ax[1].plot(tdate_predict[ind_mod],TPlake_nochange[ind_mod],'o--',color=(0,0,0.8))
p3,=ax[1].plot(tdate_compare[ind_obs],TPlake_obs[ind_obs],'ko-')
p4,=ax[1].plot(df_Muller_model["Jahr"].values,df_Muller_model["TPmod"].values,'o--',color=(0.5,0.5,0.5))
ax[1].set_ylabel('$TP_{\\rm mixed}$ [mg-P/m$^3$]')
ax[1].legend([p1,p2,p3,p4],["$TP_{\\rm mixed,mod}$","$TP_{\\rm mixed,initial\\ value}$","$TP_{\\rm mixed,obs}$","$TP_{\\rm mixed,Müller}$"])

fig.set_tight_layout(True)
fig.suptitle("{} = {:.2f} {} ({:.1f}*initial_value)".format(param_name,paramval[k_iteration],param_units,param_factor[k_iteration]))
# Out:
# Text(0.5, 0.98, 'Pin = 0.57  (0.1*initial_value)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot summarizing the sensitivity analysis
fig,ax=plt.subplots(1,3,figsize=(10,4))

p1,=ax[0].plot(param_factor,change_TPavg["Epi"],'o-',color="orange")
p2,=ax[0].plot(param_factor,change_TPavg["Hypo"],'o-',color=(0.8,0,0))
p3,=ax[0].plot(param_factor,change_TPavg["Lake"],'ko-')
ax[0].plot(1,1,'bo')
ax[0].set_xlabel("Change in tested parameter")
ax[0].set_ylabel("Change in time-averaged TP")
ax[0].set_xscale("log")
ax[0].legend([p1,p2,p3],["Epilimnion","Hypolimnion","Lake-averaged"])
#ax[0].set_yscale("log")

ax[1].plot(param_factor,change_TPstd["Epi"],'o-',color="orange")
ax[1].plot(param_factor,change_TPstd["Hypo"],'o-',color=(0.8,0,0))
ax[1].plot(param_factor,change_TPstd["Lake"],'ko-')
ax[1].plot(1,1,'bo')
ax[1].set_xlabel("Change in tested parameter")
ax[1].set_ylabel("Change in TP variability (std)")
ax[1].set_xscale("log")
#ax[1].set_yscale("log")

ax[2].plot(param_factor,change_TPtrend["Epi"],'o-',color="orange")
ax[2].plot(param_factor,change_TPtrend["Hypo"],'o-',color=(0.8,0,0))
ax[2].plot(param_factor,change_TPtrend["Lake"],'ko-')
ax[2].plot(1,1,'bo')
ax[2].set_xlabel("Change in tested parameter")
ax[2].set_ylabel("Change in TP trend")
ax[2].set_xscale("log")
#ax[2].set_yscale("log")

fig.suptitle("Parameter "+param_name)
fig.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Save figure
fig.savefig("../Figures/sensitivity_"+param_name+".png",dpi=400)
fig.savefig("../Figures/sensitivity_"+param_name+".svg")
print('Figure saved!')
# Out:
# Figure saved!
